# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.sample(6)
# Out:
#                                     property_name property_type  \
# 3092  5 Bedroom House for sale in Mianwali Colony         house
# 7                 4 BHK Flat in Sector 92 Gurgaon          flat
# 1932                    3 BHK Flat in DLF Phase 5          flat
# 3699             3 BHK Flat in Sector 103 Gurgaon          flat
# 2839     11 Bedroom House for sale in Rajiv Chowk         house
# 39                2 BHK Flat in Sector 85 Gurgaon          flat
#
#                       society  price  price_per_sqft    area  \
# 3092              independent   1.50         11111.0   125.0
# 7                  sare homes   1.19          5219.0  2280.0
# 1932     dlf exclusive floors   2.35         14242.0  1650.0
# 3699  indiabulls centrum park   1.34          7486.0  1790.0
# 2839             hans enclave   2.00         10101.0   184.0
# 39                ss the leaf   1.20         10452.0  1148.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
df.to_csv('properties_merged.csv',index=False)
